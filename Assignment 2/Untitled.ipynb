# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("StudentPerformance.csv")
print(df)
# Out:
#     Maths_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0            70             93             61               82
# 1            77             84             65               88
# 2            69             84             68               93
# 3            35             81             73               91
# 4            78             95             73               96
# 5            70             94             60               80
# 6            69             86             79               91
# 7            76             92             61               79
# 8            79             81             77               80
# 9            79             85             78               76
# 10           66             78             69               94
# 11           75             60             60               90
# 12           75             81             74               88
# 13           94             75             80               83
# ...

# %%
new_df=df
col=['Maths_Score'] #----Box Plot for finding the outliers
new_df.boxplot(col)
# Out:
# <Axes: >

# %%
fig,ax=plt.subplots(figsize=(18,10))
ax.scatter(df['Placement_Score'],df['Placement offer count'])
plt.show()#------Scatter Plot

# %%
#----code to finding the IQR
q1=np.percentile(df['Maths_Score'],25)
q3=np.percentile(df['Maths_Score'],75)
IQR=q3-q1
print(IQR)
# Out:
# 11.0

# %%
#-----Code to find the outliers and 
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound,upr_bound)
inden_outlier=np.where((df[col]<lwr_bound)|(df[col]>upr_bound))
inden_outlier
# Out:
# 51.5 95.5
# (array([ 3, 15, 19, 27], dtype=int64), array([0, 0, 0, 0], dtype=int64))

# %%
#-----Code to find the outliers and 
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound,upr_bound)
inden_outlier=np.where((df[col]<lwr_bound)|(df[col]>upr_bound))
inden_outlier
# Out:
# 51.5 95.5
# (array([ 3, 15, 19, 27], dtype=int64), array([0, 0, 0, 0], dtype=int64))
